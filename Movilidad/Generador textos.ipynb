# %%
import pandas as pd
import numpy as np
import os

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %% [markdown]
# leo desde mi carpeta una lista de la regines y sus órdenes

# %%
LISTAREGIONES = pd.read_csv('./BDs/numeroyregiones.csv').set_index('cir_sena')
LISTAREGIONES
# Out:
#                           Region
# cir_sena
# 1             Arica y Parinacota
# 2                    Antofagasta
# 3                       Tarapacá
# 4                        Atacama
# 5                       Coquimbo
# 6                     Valparaíso
# 7                  Metropolitana
# 8                      O'Higgins
# 9                          Maule
# 10                         Ñuble
# 11                       Bio Bio
# 12                     Araucania
# 13                      Los Ríos
# 14                     Los Lagos
# 15                         Aysén
# 16        Magallanes y Antártida

# %% [markdown]
# Leo el texto base donde he de reemplazar el nombre de las regiones y su numeración

# %%
F = open('./textolatex_regiones.txt','r').read()
print(F)
# Out:
# \subsubsection{Región de NOMBRE_REGION}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%
# %%%%%%   Media
#
# \begin{figure}[H]
# 	\centering
# 	\begin{adjustbox}{width=0.8\textwidth}
# 		\includegraphics{./figtab/Regionmedia_NUMERO_REGION.png} %%%%% grafo leído acá!!!
# 	\end{adjustbox}
# 	\caption{Movilidad ciudadana en la pandemia del Coronavirus19. Se presenta el indicador de movilidad basado en la cantidad visitas y duración de estas a varios tipos de localizaciones. Se muestra la media de cada semana para los indicadores de movilidad.}
# 	%\label{}
# \end{figure}
#
# \begin{table}[H]
# \begin{adjustbox}{width=1\textwidth}
# 	\input{./figtab/tab_media_regionNUMERO_REGION.tab}   %%%%% tabla leída acá!!!
# \end{adjustbox}
# ...

# %%
for index, row in LISTAREGIONES.iterrows():
    print(index)
    print(row['Region'])
    dum1 = F.replace('NOMBRE_REGION', str(row['Region'])).replace('NUMERO_REGION', str(index))
    print(dum1)
    texto_region = open('./Producto/textos/texto_region' + str(index) + '.reg','w')
    print(dum1,file=texto_region)
    texto_region.close()
    print('xo'*60 + '\n' + 'xo'*60 + '\n' + 'xo'*60 + '\n')
# Out:
# 1
# Arica y Parinacota
# \subsubsection{Región de Arica y Parinacota}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%
# %%%%%%   Media
#
# \begin{figure}[H]
# 	\centering
# 	\begin{adjustbox}{width=0.8\textwidth}
# 		\includegraphics{./figtab/Regionmedia_1.png} %%%%% grafo leído acá!!!
# 	\end{adjustbox}
# 	\caption{Movilidad ciudadana en la pandemia del Coronavirus19. Se presenta el indicador de movilidad basado en la cantidad visitas y duración de estas a varios tipos de localizaciones. Se muestra la media de cada semana para los indicadores de movilidad.}
# 	%\label{}
# \end{figure}
#
# \begin{table}[H]
# \begin{adjustbox}{width=1\textwidth}
# 	\input{./figtab/tab_media_region1.tab}   %%%%% tabla leída acá!!!
# \end{adjustbox}
# ...

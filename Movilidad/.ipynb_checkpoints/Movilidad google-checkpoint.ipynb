# %% [markdown]
# Movilidad de personas en chile
# =================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import scipy 
from scipy import stats
import datetime as dt
from datetime import timedelta  
import urllib.request  # importar archivos web
from lifelines import NelsonAalenFitter # modelamiento survival

# para tratar de poner espanol
from datetime import date, datetime, time
from babel.dates import format_date, format_datetime, format_time, format_timedelta, Locale
import locale                                    # para tratar de poner espanol
locale.setlocale(locale.LC_ALL,'es_CL.utf8')  

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %% [markdown]
# leo la base de datos desde google y la guardo

# %%
import wget

print('Bajando')
# desde esta dirección
url = 'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=b8b0c30cbee5f341'

# le pongo nombre al archivo
hoy     = datetime.now().strftime('%Y-%m-%d')
nombre  = './BDs/Movilidad' + hoy + '.csv'

# la bajo
wget.download(url, nombre)
# Out:
# Bajando
# './BDs/Movilidad2020-06-09 (1).csv'

# %%
# listo los archivos disponibles que he bajado
import os
lista_archivos = []
for dirname, dirnames, filenames in os.walk('./BDs/'):
    for filename in filenames:
        lista_archivos.append(os.path.join(dirname, filename))
archivos = lista_archivos
archivos
# Out:
# ['./BDs/Movilidad2020-06-09.csv',
#  './BDs/Movilidad2020-06-09 (1).csv',
#  './BDs/Movilidad2020-06-07.csv',
#  './BDs/Movilidad2020-06-05.csv',
#  './BDs/Movilidad2020-06-08.csv']

# %%
BD = pd.read_csv(archivos[-1])
# Out:
# /home/egidio/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
BD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477322 entries, 0 to 477321
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 476498 non-null  object
#  1   country_region                                      477322 non-null  object
#  2   sub_region_1                                        463462 non-null  object
#  3   sub_region_2                                        276591 non-null  object
#  4   date                                                477322 non-null  object
#  5   retail_and_recreation_percent_change_from_baseline  371377 non-null  float64
#  6   grocery_and_pharmacy_percent_change_from_baseline   358150 non-null  float64
#  7   parks_percent_change_from_baseline                  220621 non-null  float64
#  8   transit_stations_percent_change_from_baseline       253790 non-null  float64
#  9   workplaces_percent_change_from_baseline             464398 non-null  float64
#  10  residential_percent_change_from_baseline            262232 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 40.1+ MB

# %%
BD.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'date', 'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %% [markdown]
# Corrijo fechas

# %%
BD['date'] = pd.to_datetime(BD.date)

# %%
# Cambio nombres de columnas
BD.rename(columns={
    'retail_and_recreation_percent_change_from_baseline': 'retail_and_recreation',
    'grocery_and_pharmacy_percent_change_from_baseline': 'grocery_and_pharmacy',
    'parks_percent_change_from_baseline': 'parks',
    'transit_stations_percent_change_from_baseline': 'transit_stations',
    'workplaces_percent_change_from_baseline': 'workplaces',
    'residential_percent_change_from_baseline': 'residential'},
          inplace=True)
BD.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'date', 'retail_and_recreation', 'grocery_and_pharmacy', 'parks',
#        'transit_stations', 'workplaces', 'residential'],
#       dtype='object')

# %% [markdown]
# # Descripicón de la BD

# %%
#cantidad de países
BD.country_region.unique().shape
# Out:
# (132,)

# %%
chile = BD.loc[BD.country_region=='Chile']
valpo = chile.loc[chile.sub_region_1=='Valparaíso']
chile.sub_region_1.value_counts().index
# Out:
# Index(['O'Higgins', 'Coquimbo', 'Magallanes and Chilean Antarctica', 'Atacama',
#        'Maule', 'Tarapacá', 'Valparaíso', 'Antofagasta', 'Arica y Parinacota',
#        'Ñuble', 'Araucania', 'Santiago Metropolitan Region', 'Aysén',
#        'Los Lagos', 'Los Ríos', 'Bio Bio'],
#       dtype='object')

# %%
chile.groupby(['sub_region_1','date']).retail_and_recreation.mean()
# chile.groupby(['sub_region_1','date']).get_group(("O'Higgins"))

fig, ax = plt.subplots()
chile.groupby(['sub_region_1']).plot(x='date',
          y='retail_and_recreation',
          ax=ax)
plt.legend('')
# Out:
# sub_region_1  date
# Antofagasta   2020-02-15     2.0
#               2020-02-16     2.0
#               2020-02-17    -1.0
#               2020-02-18    -1.0
#               2020-02-19    -5.0
#                             ...
# Ñuble         2020-05-25   -45.0
#               2020-05-26   -48.0
#               2020-05-27   -48.0
#               2020-05-28   -50.0
#               2020-05-29   -48.0
# Name: retail_and_recreation, Length: 1680, dtype: float64
# sub_region_1
# Antofagasta                          AxesSubplot(0.125,0.125;0.775x0.755)
# Araucania                            AxesSubplot(0.125,0.125;0.775x0.755)
# Arica y Parinacota                   AxesSubplot(0.125,0.125;0.775x0.755)
# Atacama                              AxesSubplot(0.125,0.125;0.775x0.755)
# Aysén                                AxesSubplot(0.125,0.125;0.775x0.755)
# Bio Bio                              AxesSubplot(0.125,0.125;0.775x0.755)
# Coquimbo                             AxesSubplot(0.125,0.125;0.775x0.755)
# Los Lagos                            AxesSubplot(0.125,0.125;0.775x0.755)
# Los Ríos                             AxesSubplot(0.125,0.125;0.775x0.755)
# Magallanes and Chilean Antarctica    AxesSubplot(0.125,0.125;0.775x0.755)
# Maule                                AxesSubplot(0.125,0.125;0.775x0.755)
# O'Higgins                            AxesSubplot(0.125,0.125;0.775x0.755)
# Santiago Metropolitan Region         AxesSubplot(0.125,0.125;0.775x0.755)
# Tarapacá                             AxesSubplot(0.125,0.125;0.775x0.755)
# Valparaíso                           AxesSubplot(0.125,0.125;0.775x0.755)
# Ñuble                                AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# fig, ax = plt.subplots()
agrupado = chile.groupby(['sub_region_1',chile.date.dt.week])
dum = agrupado.parks.mean().unstack()
dum
agrupado.parks.mean().unstack().T.plot()
# agrupado.parks.mean().groupby('date').agg('sd')
# agrupado.groups.keys()
# Out:
# date                                 7          8          9          10  \
# sub_region_1
# Antofagasta                        -0.5  -5.000000 -11.285714 -16.000000
# Araucania                          27.0  24.571429  -7.000000 -25.857143
# Arica y Parinacota                  1.0  -6.571429 -14.142857 -28.571429
# Atacama                            10.0  11.142857  -5.857143 -22.000000
# Aysén                              -5.5  11.142857   0.571429  -9.428571
# Bio Bio                             6.5   1.000000  -8.571429 -19.714286
# Coquimbo                           33.0  31.142857 -12.285714 -39.714286
# Los Lagos                           9.5  29.714286  -1.571429 -21.142857
# Los Ríos                           28.5  44.857143   4.285714 -39.285714
# Magallanes and Chilean Antarctica   2.0   5.571429  -2.000000  -1.857143
# Maule                              18.5  18.285714  -5.142857 -17.714286
# O'Higgins                          16.0  20.142857  -3.714286 -15.714286
# Magallanes and Chilean Antarctica -64.142857 -60.000000 -61.714286 -53.6
# Maule                             -46.857143 -51.571429 -54.857143 -49.8
# O'Higgins                         -48.142857 -52.000000 -56.142857 -51.8
# Santiago Metropolitan Region      -51.000000 -61.571429 -70.285714 -66.2
# Tarapacá                          -61.428571 -69.571429 -85.285714 -81.0
# Valparaíso                        -65.000000 -68.714286 -70.571429 -66.8
# Ñuble                             -44.000000 -45.428571 -48.571429 -40.8

# %%
valpo.head()
# Out:
#       country_region_code country_region sub_region_1 sub_region_2       date  \
# 24703                  CL          Chile   Valparaíso          NaN 2020-02-15
# 24704                  CL          Chile   Valparaíso          NaN 2020-02-16
# 24705                  CL          Chile   Valparaíso          NaN 2020-02-17
# 24706                  CL          Chile   Valparaíso          NaN 2020-02-18
# 24707                  CL          Chile   Valparaíso          NaN 2020-02-19
#
#        retail_and_recreation  grocery_and_pharmacy  parks  transit_stations  \
# 24703                   11.0                   9.0   16.0               9.0
# 24704                    9.0                  10.0   10.0               9.0
# 24705                    9.0                  13.0   21.0               7.0
# 24706                   10.0                  13.0   22.0               6.0
# 24707                   10.0                  14.0   21.0               6.0
#
#        workplaces  residential
# 24703        -2.0         -1.0
# 24704         0.0          0.0
# 24705        -6.0          1.0
# 24706        -4.0          1.0
# 24707        -4.0          1.0

# %%
#graficador movilidad
def graf_movilidad(db, variables, fecha_inicio, leyenda=None):
    variables
    f_fin = dt.datetime.now()
    f_inicio = dt.datetime(2020,2,16)
    
    # Grafico
    fig, ax = plt.subplots()
    dum.plot(x='date',
              y=variables,
              ax=ax)
    plt.xlabel('Fecha')
    plt.ylabel('Cambio % respecto al basal previo')
    plt.title('Movilidad ciudadana en base a servicio Google \n y localización GPS del celular')
    plt.text(f_inicio, -0,
             'Dr E Céspedes \nSAMU Viña del Mar',
             fontsize=10,
             color='gray',
             alpha=0.5)
    plt.legend(leyenda)

# %%
# Graficador movilidad en chile
dum = BD.loc[
    (BD.country_region == 'Chile') &
     (BD.sub_region_1 == 'Valparaíso')
            ]

for region in dum.sub_region_1.unique():
    print(region)
graf_movilidad(dum,
           variables = ['retail_and_recreation', 'grocery_and_pharmacy', 'parks',	'transit_stations', 'workplaces'],
           leyenda   = ['Retail y recreación', 'Farmacia y Supermercados', 'Plazas y parques',	'Transporte Público', 'Lugar de trabajo'],
           fecha_inicio=dt.datetime(2020,4,16)
          )
# Out:
# Valparaíso

# %%
dum.sub_region_1.unique()
# Out:
# array(['Valparaíso'], dtype=object)

# %%
cols = ['retail_and_recreation', 'grocery_and_pharmacy', 'parks',	'transit_stations', 'workplaces']

f_inicio = dt.datetime(2020,4,1)
valpo = valpo.loc[valpo.date>f_inicio]
indicadores = valpo.groupby([valpo.date.dt.day_name()])
indicadores.retail_and_recreation.agg(['mean','std'])
# Out:
#                 mean       std
# date
# Friday    -64.777778  9.679589
# Monday    -57.875000  2.295181
# Saturday  -64.500000  5.631544
# Sunday    -73.125000  3.090885
# Thursday  -60.000000  6.363961
# Tuesday   -58.500000  2.672612
# Wednesday -58.375000  2.326094

# %%
valpo.date.dt.day_name()
